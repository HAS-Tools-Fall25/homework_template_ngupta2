# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read.csv('/workspaces/homework_template_ngupta2/homework_submissions/TimeSeries_Q_ManID_EventOnly.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = pd.read.csv('/workspaces/homework_template_ngupta2/homework_submissions/TimeSeries_Q_ManID_EventOnly.csv')
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
df = pd.read_csv('TimeSeries_Q_ManID_EventOnly.csv',index_col = 0)
df ['Date + Minute'] = pd.to_datetime(df['Date + Minute'])
site_list = df.index.unique()
site_list
print(site_list)
# Out:
# Index(['ALM', 'AUT', 'MTN', 'VE'], dtype='object', name='Site')

# %%
site_list = df.index.unique()

# %%
for site in site_list:
    sub = df.loc[site]
    sub.index = sub['Date + Minute']
    sub['Volume (m3)'].plot(linestyle='', marker = 'o', label = site)

# %%
!
